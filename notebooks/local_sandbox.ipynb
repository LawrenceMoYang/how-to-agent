# %%
import requests
from bs4 import BeautifulSoup
import os
import urllib.parse

CONTENT_PATH = "demos/demo_v0/reources/sellercenter_crawl/htmls"
SRC_URL_FOR_SELLER_HOWTO = "https://www.ebay.com/sellercenter/selling"

def download_links_with_keyword(url, target_dir, keyword="sellercenter"):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    crawled_links = set()  # Set to keep track of crawled URLs
    filename_to_link = {}
    
    try:
        # Send a request to get the HTML content of the page
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()  # Ensure we get a valid response
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all links containing the keyword
        links = [a['href'] for a in soup.find_all('a', href=True) if keyword in a['href']]

        # Create the target directory if it doesn't exist
        if not os.path.exists(target_dir):
            os.makedirs(target_dir)

        for link in links:
            # Check if link is already absolute
            if not link.startswith("http"):
                link = "https://www.ebay.com/" + link.lstrip('/')

            # Check if link has been crawled already
            if link in crawled_links:
                print(f"Skipped (already crawled): {link}")
                continue

            # Extract the last part of the URL as the file name
            parsed_url = urllib.parse.urlparse(link)
            file_name = urllib.parse.quote(parsed_url.path.split('/')[-1]) or 'index'  # Handle cases with trailing slashes

            # Construct the file path
            file_path = os.path.join(target_dir, f"{file_name}.html")

            # Download the content of each link
            try:
                file_response = requests.get(link, headers=headers, timeout=10)
                file_response.raise_for_status()
                filename_to_link[file_path] = link

                with open(file_path, 'wb') as file:
                    file.write(file_response.content)

                print(f"Downloaded: {link} -> {file_path}")
                crawled_links.add(link)  # Mark this link as crawled

            except requests.exceptions.RequestException as e:
                print(f"Failed to download {link}: {e}")

    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve the main page: {e}")

    return filename_to_link

# %%
# Usage
filename_to_link = download_links_with_keyword(SRC_URL_FOR_SELLER_HOWTO, CONTENT_PATH)
# Out:
# Downloaded: https://www.ebay.com/sellercenter -> demos/demo_v0/reources/sellercenter_crawl/htmls/sellercenter.html
# Downloaded: https://www.ebay.com/sellercenter/selling -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling.html
# Downloaded: https://www.ebay.com/sellercenter/selling/start-selling-on-ebay -> demos/demo_v0/reources/sellercenter_crawl/htmls/start-selling-on-ebay.html
# Downloaded: https://www.ebay.com/sellercenter/selling/what-to-sell -> demos/demo_v0/reources/sellercenter_crawl/htmls/what-to-sell.html
# Downloaded: https://www.ebay.com/sellercenter/selling/how-to-sell -> demos/demo_v0/reources/sellercenter_crawl/htmls/how-to-sell.html
# Downloaded: https://www.ebay.com/sellercenter/selling/seller-fees -> demos/demo_v0/reources/sellercenter_crawl/htmls/seller-fees.html
# Downloaded: https://www.ebay.com/sellercenter/payments-and-fees/payments-and-earnings -> demos/demo_v0/reources/sellercenter_crawl/htmls/payments-and-earnings.html
# Downloaded: https://www.ebay.com/sellercenter/selling/set-up-your-store -> demos/demo_v0/reources/sellercenter_crawl/htmls/set-up-your-store.html
# Downloaded: https://www.ebay.com/sellercenter/selling/customer-service-tips -> demos/demo_v0/reources/sellercenter_crawl/htmls/customer-service-tips.html
# Downloaded: https://www.ebay.com/sellercenter/selling/seller-protections -> demos/demo_v0/reources/sellercenter_crawl/htmls/seller-protections.html
# Downloaded: https://www.ebay.com/sellercenter/selling/selling-clothes -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling-clothes.html
# Downloaded: https://www.ebay.com/sellercenter/selling/selling-jewelry -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling-jewelry.html
# Downloaded: https://www.ebay.com/sellercenter/selling/selling-luxury-bags-and-accessories -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling-luxury-bags-and-accessories.html
# Downloaded: https://www.ebay.com/sellercenter/selling/selling-luxury-watches -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling-luxury-watches.html
# Downloaded: https://www.ebay.com/sellercenter/selling/selling-sneakers -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling-sneakers.html
# Downloaded: https://www.ebay.com/sellercenter/selling/selling-trading-cards -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling-trading-cards.html
# Downloaded: https://www.ebay.com/sellercenter/selling/ebay-live -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-live.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-for-business.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/ebay-open -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-open.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/up-and-running-grants -> demos/demo_v0/reources/sellercenter_crawl/htmls/up-and-running-grants.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/ebay-academy -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-academy.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/ebay-fitment-plus -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-fitment-plus.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/ebay-refurbished-program -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-refurbished-program.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/great-price-badge -> demos/demo_v0/reources/sellercenter_crawl/htmls/great-price-badge.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/multi-user-account-access -> demos/demo_v0/reources/sellercenter_crawl/htmls/multi-user-account-access.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/seller-hub -> demos/demo_v0/reources/sellercenter_crawl/htmls/seller-hub.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/small-business-central -> demos/demo_v0/reources/sellercenter_crawl/htmls/small-business-central.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/subscriber-discounts -> demos/demo_v0/reources/sellercenter_crawl/htmls/subscriber-discounts.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/ebay-stores-shopping-experience -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-stores-shopping-experience.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/third-party-providers -> demos/demo_v0/reources/sellercenter_crawl/htmls/third-party-providers.html
# Downloaded: https://www.ebay.com/sellercenter/ebay-for-business/verified-rights-owner-program -> demos/demo_v0/reources/sellercenter_crawl/htmls/verified-rights-owner-program.html
# Downloaded: https://www.ebay.com/sellercenter/listings -> demos/demo_v0/reources/sellercenter_crawl/htmls/listings.html
# Downloaded: https://www.ebay.com/sellercenter/listings/ebay-bulk-listing-tools -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-bulk-listing-tools.html
# Downloaded: https://www.ebay.com/sellercenter/listings/ebay-price-guarantee -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-price-guarantee.html
# Downloaded: https://www.ebay.com/sellercenter/listings/item-specifics -> demos/demo_v0/reources/sellercenter_crawl/htmls/item-specifics.html
# Downloaded: https://www.ebay.com/sellercenter/listings/list-with-fitment -> demos/demo_v0/reources/sellercenter_crawl/htmls/list-with-fitment.html
# Downloaded: https://www.ebay.com/sellercenter/listings/listing-best-practices -> demos/demo_v0/reources/sellercenter_crawl/htmls/listing-best-practices.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/listings/listing-best-practices
# Downloaded: https://www.ebay.com/sellercenter/listings/perfect-cell-phone-listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/perfect-cell-phone-listing.html
# Downloaded: https://www.ebay.com/sellercenter/listings/perfect-desktop-or-laptop-listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/perfect-desktop-or-laptop-listing.html
# Downloaded: https://www.ebay.com/sellercenter/listings/perfect-smartwatch-listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/perfect-smartwatch-listing.html
# Downloaded: https://www.ebay.com/sellercenter/listings/perfect-tablet-listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/perfect-tablet-listing.html
# Downloaded: https://www.ebay.com/sellercenter/listings/product-identifiers -> demos/demo_v0/reources/sellercenter_crawl/htmls/product-identifiers.html
# Downloaded: https://www.ebay.com/sellercenter/listings/seller-uploaded-videos -> demos/demo_v0/reources/sellercenter_crawl/htmls/seller-uploaded-videos.html
# Downloaded: https://www.ebay.com/sellercenter/listings/share-to-social -> demos/demo_v0/reources/sellercenter_crawl/htmls/share-to-social.html
# Downloaded: https://www.ebay.com/sellercenter/listings/photo-tips -> demos/demo_v0/reources/sellercenter_crawl/htmls/photo-tips.html
# Downloaded: https://www.ebay.com/sellercenter/growth -> demos/demo_v0/reources/sellercenter_crawl/htmls/growth.html
# Downloaded: https://www.ebay.com/sellercenter/growth/ebay-partner-network -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-partner-network.html
# Downloaded: https://www.ebay.com/sellercenter/growth/ebay-research-tools -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-research-tools.html
# Downloaded: https://www.ebay.com/sellercenter/growth/ebay-advertising -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-advertising.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/growth/ebay-advertising
# Downloaded: https://www.ebay.com/sellercenter/growth/ebay-advertising/promoted-listings -> demos/demo_v0/reources/sellercenter_crawl/htmls/promoted-listings.html
# Downloaded: https://www.ebay.com/sellercenter/growth/ebay-advertising/promoted-stores -> demos/demo_v0/reources/sellercenter_crawl/htmls/promoted-stores.html
# Downloaded: https://www.ebay.com/sellercenter/growth/ebay-advertising/promoted-offsite -> demos/demo_v0/reources/sellercenter_crawl/htmls/promoted-offsite.html
# Downloaded: https://www.ebay.com/sellercenter/growth/going-global -> demos/demo_v0/reources/sellercenter_crawl/htmls/going-global.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/growth/going-global
# Downloaded: https://www.ebay.com/sellercenter/growth/going-global/german-packaging-act -> demos/demo_v0/reources/sellercenter_crawl/htmls/german-packaging-act.html
# Downloaded: https://www.ebay.com/sellercenter/growth/promotion-strategies -> demos/demo_v0/reources/sellercenter_crawl/htmls/promotion-strategies.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts -> demos/demo_v0/reources/sellercenter_crawl/htmls/seller-hub-discounts.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/growth/seller-hub-discounts
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/buyer-groups -> demos/demo_v0/reources/sellercenter_crawl/htmls/buyer-groups.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/coded-coupons -> demos/demo_v0/reources/sellercenter_crawl/htmls/coded-coupons.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/sale-events -> demos/demo_v0/reources/sellercenter_crawl/htmls/sale-events.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/offers-to-buyers-best-offer -> demos/demo_v0/reources/sellercenter_crawl/htmls/offers-to-buyers-best-offer.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/order-size-discounts -> demos/demo_v0/reources/sellercenter_crawl/htmls/order-size-discounts.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/shipping-discounts -> demos/demo_v0/reources/sellercenter_crawl/htmls/shipping-discounts.html
# Downloaded: https://www.ebay.com/sellercenter/growth/seller-hub-discounts/volume-pricing -> demos/demo_v0/reources/sellercenter_crawl/htmls/volume-pricing.html
# Downloaded: https://www.ebay.com/sellercenter/shipping -> demos/demo_v0/reources/sellercenter_crawl/htmls/shipping.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/preparing-your-shipment -> demos/demo_v0/reources/sellercenter_crawl/htmls/preparing-your-shipment.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/shipping/preparing-your-shipment
# Downloaded: https://www.ebay.com/sellercenter/shipping/preparing-your-shipment/packaging-and-measuring -> demos/demo_v0/reources/sellercenter_crawl/htmls/packaging-and-measuring.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/preparing-your-shipment/handling-time -> demos/demo_v0/reources/sellercenter_crawl/htmls/handling-time.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/preparing-your-shipment/know-what-qualifies-as-hazmat -> demos/demo_v0/reources/sellercenter_crawl/htmls/know-what-qualifies-as-hazmat.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service -> demos/demo_v0/reources/sellercenter_crawl/htmls/choosing-a-carrier-and-service.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service
# Downloaded: https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service/usps-and-ebay-labels -> demos/demo_v0/reources/sellercenter_crawl/htmls/usps-and-ebay-labels.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service/fedex-and-ebay-labels -> demos/demo_v0/reources/sellercenter_crawl/htmls/fedex-and-ebay-labels.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service/ups-and-ebay-labels -> demos/demo_v0/reources/sellercenter_crawl/htmls/ups-and-ebay-labels.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/ebay-international-shipping -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-international-shipping.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service/freight -> demos/demo_v0/reources/sellercenter_crawl/htmls/freight.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/choosing-a-carrier-and-service/ebay-standard-envelope -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-standard-envelope.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/managing-returns -> demos/demo_v0/reources/sellercenter_crawl/htmls/managing-returns.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/holiday-shipping -> demos/demo_v0/reources/sellercenter_crawl/htmls/holiday-shipping.html
# Downloaded: https://www.ebay.com/sellercenter/shipping/faqs -> demos/demo_v0/reources/sellercenter_crawl/htmls/faqs.html
# Downloaded: https://www.ebay.com/sellercenter/protections -> demos/demo_v0/reources/sellercenter_crawl/htmls/protections.html
# Downloaded: https://www.ebay.com/sellercenter/protections/defect-removal -> demos/demo_v0/reources/sellercenter_crawl/htmls/defect-removal.html
# Downloaded: https://www.ebay.com/sellercenter/protections/returns -> demos/demo_v0/reources/sellercenter_crawl/htmls/returns.html
# Downloaded: https://www.ebay.com/sellercenter/protections/seller-help -> demos/demo_v0/reources/sellercenter_crawl/htmls/seller-help.html
# Downloaded: https://www.ebay.com/sellercenter/protections/top-rated-program -> demos/demo_v0/reources/sellercenter_crawl/htmls/top-rated-program.html
# Downloaded: https://www.ebay.com/sellercenter/protections/ebay-guaranteed-fit -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-guaranteed-fit.html
# Downloaded: https://www.ebay.com/sellercenter/payments-and-fees -> demos/demo_v0/reources/sellercenter_crawl/htmls/payments-and-fees.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/payments-and-fees/payments-and-earnings
# Downloaded: https://www.ebay.com/sellercenter/payments-and-fees/payouts-on-demand -> demos/demo_v0/reources/sellercenter_crawl/htmls/payouts-on-demand.html
# Downloaded: https://www.ebay.com/sellercenter/payments-and-fees/express-payouts -> demos/demo_v0/reources/sellercenter_crawl/htmls/express-payouts.html
# Downloaded: https://www.ebay.com/sellercenter/payments-and-fees/subscriptions-and-fees -> demos/demo_v0/reources/sellercenter_crawl/htmls/subscriptions-and-fees.html
# Downloaded: https://www.ebay.com/sellercenter/resources -> demos/demo_v0/reources/sellercenter_crawl/htmls/resources.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/timeline -> demos/demo_v0/reources/sellercenter_crawl/htmls/timeline.html
# Skipped (already crawled): https://www.ebay.com/sellercenter/resources/seller-updates/timeline
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-october -> demos/demo_v0/reources/sellercenter_crawl/htmls/2024-october.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-october/tools -> demos/demo_v0/reources/sellercenter_crawl/htmls/tools.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-october/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-october/protections -> demos/demo_v0/reources/sellercenter_crawl/htmls/protections.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-summer -> demos/demo_v0/reources/sellercenter_crawl/htmls/2024-summer.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-summer/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-summer/tools -> demos/demo_v0/reources/sellercenter_crawl/htmls/tools.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-summer/operations -> demos/demo_v0/reources/sellercenter_crawl/htmls/operations.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-winter -> demos/demo_v0/reources/sellercenter_crawl/htmls/2024-winter.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-winter/financials -> demos/demo_v0/reources/sellercenter_crawl/htmls/financials.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-winter/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-winter/tools -> demos/demo_v0/reources/sellercenter_crawl/htmls/tools.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2024-winter/protections -> demos/demo_v0/reources/sellercenter_crawl/htmls/protections.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-fall -> demos/demo_v0/reources/sellercenter_crawl/htmls/2023-fall.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-fall/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-fall/listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/listing.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-fall/financials -> demos/demo_v0/reources/sellercenter_crawl/htmls/financials.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-fall/shipping -> demos/demo_v0/reources/sellercenter_crawl/htmls/shipping.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-summer -> demos/demo_v0/reources/sellercenter_crawl/htmls/2023-summer.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-summer/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-summer/listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/listing.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-summer/financials -> demos/demo_v0/reources/sellercenter_crawl/htmls/financials.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-summer/shipping -> demos/demo_v0/reources/sellercenter_crawl/htmls/shipping.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-winter -> demos/demo_v0/reources/sellercenter_crawl/htmls/2023-winter.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-winter/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2023-winter/financials -> demos/demo_v0/reources/sellercenter_crawl/htmls/financials.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-fall -> demos/demo_v0/reources/sellercenter_crawl/htmls/2022-fall.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-fall/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-fall/listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/listing.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-fall/shipping -> demos/demo_v0/reources/sellercenter_crawl/htmls/shipping.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-spring -> demos/demo_v0/reources/sellercenter_crawl/htmls/2022-spring.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-spring/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-spring/listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/listing.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-spring/financials -> demos/demo_v0/reources/sellercenter_crawl/htmls/financials.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-winter -> demos/demo_v0/reources/sellercenter_crawl/htmls/2022-winter.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-winter/business -> demos/demo_v0/reources/sellercenter_crawl/htmls/business.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-winter/listing -> demos/demo_v0/reources/sellercenter_crawl/htmls/listing.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seller-updates/2022-winter/financials -> demos/demo_v0/reources/sellercenter_crawl/htmls/financials.html
# Downloaded: https://www.ebay.com/sellercenter/resources/general-product-safety-regulation -> demos/demo_v0/reources/sellercenter_crawl/htmls/general-product-safety-regulation.html
# Downloaded: https://www.ebay.com/sellercenter/resources/digital-services-act -> demos/demo_v0/reources/sellercenter_crawl/htmls/digital-services-act.html
# Downloaded: https://www.ebay.com/sellercenter/resources/inform-consumers-act -> demos/demo_v0/reources/sellercenter_crawl/htmls/inform-consumers-act.html
# Downloaded: https://www.ebay.com/sellercenter/resources/changes-to-ebay-and-your-1099-k -> demos/demo_v0/reources/sellercenter_crawl/htmls/changes-to-ebay-and-your-1099-k.html
# Downloaded: https://www.ebay.com/sellercenter/resources/ebay-and-taxact-partnership -> demos/demo_v0/reources/sellercenter_crawl/htmls/ebay-and-taxact-partnership.html
# Downloaded: https://www.ebay.com/sellercenter/resources/tax-information -> demos/demo_v0/reources/sellercenter_crawl/htmls/tax-information.html
# Downloaded: https://www.ebay.com/sellercenter/resources/seasonal-playbook -> demos/demo_v0/reources/sellercenter_crawl/htmls/seasonal-playbook.html
# Skipped (already crawled): https://www.ebay.com/sellercenter
# Skipped (already crawled): https://www.ebay.com/sellercenter/selling/start-selling-on-ebay
# Skipped (already crawled): https://www.ebay.com/sellercenter/selling/set-up-your-store
# Skipped (already crawled): https://www.ebay.com/sellercenter/payments-and-fees/payments-and-earnings
# Skipped (already crawled): https://www.ebay.com/sellercenter/selling/seller-protections
# Downloaded: https://www.ebay.com/srv/survey/a/selling.sellercenter?ctx_pageInstanceId=36414323-0cc1-0024-0e7d-092138f6cb97&ctx_pageTitle=Selling+%7C+Seller+Center&pageId=3137842 -> demos/demo_v0/reources/sellercenter_crawl/htmls/selling.sellercenter.html

# %%
import pickle
LIB = "../demos/demo_v0/resources/sellercenter_crawl/"
with open(LIB + "filename_to_link", 'wb') as f:
    pickle.dump(filename_to_link, f)

# %% [markdown]
# # To complete the RAG, here is a code to index the webpages:

# %%
import os
import faiss
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel
from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer

# Load the Llama-based embedding model
model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(model_name)

def extract_text_from_html(file_path):
    """Extracts only relevant text content from an HTML file, filtering out links, tags, and other non-essential elements."""
    with open(file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
        
        # Remove unnecessary elements (e.g., scripts, styles, navigation links)
        for element in soup(['script', 'style', 'nav', 'footer', 'header', 'aside', 'form', 'noscript']):
            element.extract()
        
        # Extract text from main content tags
        content = []
        
        for tag in soup.find_all(['h1', 'h2', 'h3', 'p', 'li']):
            text = tag.get_text(separator=" ", strip=True)
            if text:  # Only add non-empty text
                content.append(text)
        
        # Join the extracted text with line breaks for readability
        relevant_text = "\n".join(content)
        
    return relevant_text

def generate_embeddings(texts):
    """Generates embeddings for a list of texts using the embedding model."""
    return embedder.encode(texts, convert_to_tensor=True)

def build_index(embeddings):
    """Builds a FAISS index for the provided embeddings."""
    dimension = embeddings.shape[1]  # Get embedding dimension
    index = faiss.IndexFlatL2(dimension)  # L2 distance for similarity search
    index.add(embeddings)  # Add embeddings to the index
    return index

def prepare_documents_and_index(directory):
    """Prepares documents by reading HTML files, generating embeddings, and building an index."""
    documents = []
    filenames = []  # Store filenames associated with each document
    embeddings = []

    # Process each HTML file in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        if filename.endswith('.html'):
            # Extract text content from the HTML file
            text = extract_text_from_html(file_path)
            print(f"Extracted content from {filename}:\n{text}\n")  # Print extracted content

            # Append the extracted text and filename to lists
            documents.append(text)
            filenames.append(filename)
            
            # Generate and store embedding
            embedding = generate_embeddings([text])[0]
            embeddings.append(embedding)

    # Stack embeddings into a single numpy array
    embeddings = torch.stack(embeddings).cpu().detach().numpy()

    # Build FAISS index
    index = build_index(embeddings)
    return documents, filenames, index

def search(query, documents, filenames, index, top_k=5):
    """Searches for the top-k most similar documents to the query."""
    # Generate embedding for the query
    query_embedding = generate_embeddings([query])[0].cpu().detach().numpy().reshape(1, -1)

    # Perform search in the FAISS index
    _, indices = index.search(query_embedding, top_k)

    # Retrieve the corresponding documents and filenames
    results = [{"text": documents[i], "filename": filenames[i]} for i in indices[0]]
    return results

# %%
# Usage
directory = "downloads_encoded_names"
documents, filenames, index = prepare_documents_and_index(directory)

# %% [markdown]
# # Code to answer the questions

# %%
from pychomsky.chchat import AzureOpenAIChatWrapper
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

MODEL_NAME = "openai-chat-completions-gpt-3.5-turbo-0125"
#MODEL_NAME = "ebay-internal-chat-completions-ellama-3-8b-instruct"

def answer_question(question, filename_to_link, documents, filenames, index):
    results = search(question, documents, filenames, index)
    conversation = ConversationChain(
        llm=AzureOpenAIChatWrapper( model_name=MODEL_NAME), 
        memory=ConversationBufferMemory(),
        verbose=False
    )
    prompt = "\n".join(["Given the following retrieved paragraph from eBay's support page:\n",
            "Parapgraph",
            results[0]['text'], 
            "From the webpage:",
            filename_to_link[CONTENT_PATH + "/" + results[0]['filename']],
            "Summarize all the relevant data to answer the following questoin:",
            question,
            "and provide a link to the original webpage"])
    return conversation.predict(input=prompt)

# %%
question = "what happens if the buyer returns a good item?"
print(answer_question(question, filename_to_link, documents, filenames, index))

# %% [markdown]
# If the buyer returns a good item, the seller may still need to issue a refund to the buyer as per the return policy. The seller can issue the refund directly from the Return Details screen after inspecting the item. The specific details and process for handling a return can be found on eBay's support page for managing returns, which can be accessed through the following link: <https://www.ebay.com/sellercenter/protections/returns>.

# %%
import os
import faiss
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel
from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer


def extract_text_from_html(file_path):
    """Extracts only relevant text content from an HTML file, filtering out links, tags, and other non-essential elements."""
    with open(file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')

        # Remove unnecessary elements (e.g., scripts, styles, navigation links)
        for element in soup(['script', 'style', 'nav', 'footer', 'header', 'aside', 'form', 'noscript']):
            element.extract()

        # Extract text from main content tags
        content = []

        for tag in soup.find_all(['h1', 'h2', 'h3', 'p', 'li']):
            text = tag.get_text(separator=" ", strip=True)
            if text:  # Only add non-empty text
                content.append(text)

        # Join the extracted text with line breaks for readability
        relevant_text = "\n".join(content)

    return relevant_text


def generate_embeddings(texts):
    embedder = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
    """Generates embeddings for a list of texts using the embedding model."""
    return embedder.encode(texts, convert_to_tensor=True)


def build_faiss_index(embeddings):
    """Builds a FAISS index for the provided embeddings."""
    dimension = embeddings.shape[1]  # Get embedding dimension
    index = faiss.IndexFlatL2(dimension)  # L2 distance for similarity search
    index.add(embeddings)  # Add embeddings to the index
    return index


def split_into_chunks(text, chunk_size=256, overlap=50):
    """
    Splits text into chunks of specified token length with overlap.

    Parameters:
        text (str): The text to split.
        chunk_size (int): Number of tokens per chunk.
        overlap (int): Number of tokens to overlap between chunks.

    Returns:
        list of str: List of text chunks.
    """
    tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-mpnet-base-v2")
    tokens = tokenizer.encode(text, add_special_tokens=False)
    chunks = []

    for i in range(0, len(tokens), chunk_size - overlap):
        chunk_tokens = tokens[i:i + chunk_size]
        chunk_text = tokenizer.decode(chunk_tokens, skip_special_tokens=True)
        chunks.append(chunk_text)

    return chunks



def build_index(directory_list):
    """Prepares documents by reading HTML files, generating embeddings, and building an index."""
    documents = []
    filenames = []  # Store filenames associated with each document
    embeddings = []

    # Process all directories.
    for directory in directory_list:
        # Process each HTML file in the directory
        for filename in os.listdir(directory):
            file_path = os.path.join(directory, filename)
            if filename.endswith('.html'):
                # Extract text content from the HTML file
                text = extract_text_from_html(file_path)
                print(f"Extracted content from {filename}:\n{text}\n")  # Print extracted content

                # Split the text into chunks
                text_chunks = split_into_chunks(text)

                for chunk_index, chunk in enumerate(text_chunks):
                    print("handling chunk " , str(chunk_index))
                    # Append each chunk and metadata to lists
                    documents.append(chunk)
                    filenames.append((filename, chunk_index))  # Track filename and chunk index

                    # Generate and store embedding for each chunk
                    embedding = generate_embeddings([chunk])[0]
                    embeddings.append(embedding)

    # Stack embeddings into a single numpy array
    embeddings = torch.stack(embeddings).cpu().detach().numpy()

    # Build FAISS index
    index = build_faiss_index(embeddings)
    return documents, filenames, index

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
documents, filenames, index = build_index(["demos/demo_v0/reources/sellercenter_crawl"])
# Out:
# Extracted content from listings.html:
# Create great listings
# Listings are your window to millions of potential buyers on eBay.
# Listing best practices
# Get your listings looking great with these basic tips. Learn how to write effective titles and descriptions, select the best categories, and much more.
# Make your listings stand out
# Help your potential buyers find your listings when using search and filters, and learn how you can future-proof your listings with item specifics.
# Take great photos
# Successful listings start with great photos. Check out our tips and tricks for getting great product images for your eBay listings.
# Offer competitive prices
# eBay’s Research Tools help you price your items competitively and maximize sales.
# Manage your listings
# Find advanced listing tools and features to help you create, update, and manage listings as your business grows.
#
# handling chunk  create great listings listings are your window to millions of potential buyers on ebay. listing best practices get your listings looking great with these basic tips. learn how to write effective titles and descriptions, select the best categories, and much more. make your listings stand out help your potential buyers find your listings when using search and filters, and learn how you can future - proof your listings with item specifics. take great photos successful listings start with great photos. check out our tips and tricks for getting great product images for your ebay listings. offer competitive prices ebay ’ s research tools help you price your items competitively and maximize sales. manage your listings find advanced listing tools and features to help you create, update, and manage listings as your business grows.
